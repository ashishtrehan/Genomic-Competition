# %%
source = "jiKnp4bqpmAbp"
target = "Hello, World!"

# %%
import random

# %%
def fitness(source, target):
   fitval = 0
   for i in range(0, len(source)):
      fitval += (ord(target[i]) - ord(source[i])) ** 2
   return(fitval)

# %%
def mutate(source):
   charpos = random.randint(0, len(source) - 1)
   parts = list(source)
   parts[charpos] = chr(ord(parts[charpos]) + random.randint(-1,1))
   return(''.join(parts))

# %%
fitval = fitness(source, target)
i = 0
while True:
   i += 1
   m = mutate(source)
   fitval_m = fitness(m, target)
   if fitval_m < fitval:
      fitval = fitval_m
      source = m
      print "%5i %5i %14s" % (i, fitval_m, m)
   if fitval == 0:
      break
# Out:
#     2 15431  jiKnp4bppmAbp
#     3 15416  jiKnp3bppmAbp
#     7 15285  jiKnp3appmAbp
#     8 15282  jiKmp3appmAbp
#     9 15281  jiKmp3apomAbp
#    10 15232  jiKmp3aoomAbp
#    12 15223  jiKmp3aoonAbp
#    17 15220  jiKmp3aoonAcp
#    18 15219  jiKmp3aoonAdp
#    24 15090  jiKmp3`oonAdp
#    27 15043  jiKmp3`nonAdp
#    39 15042  jiKlp3`nonAdp
#    41 15041  jiKlo3`nonAdp
#    42 14914  jiKlo3_nonAdp
#    43 14789  jiKlo3^nonAdp
#    44 14722  iiKlo3^nonAdp
#    48 14599  iiKlo3]nonAdp
#    49 14592  iiKlo3]nooAdp
#    51 14527  hiKlo3]nooAdp
#    54 14442  hiKlo3]nooBdp
#    55 14321  hiKlo3\nooBdp
#    58 14276  hiKlo3\mooBdp
#    59 14211  hiLlo3\mooBdp
#    60 14054  hiLlo3\mooBdo
#    61 13991  hiMlo3\mooBdo
#    71 13984  hhMlo3\mooBdo
#    76 13921  ghMlo3\mooBdo
#    79 13916  ghMlo3\mopBdo
#    82 13761  ghMlo3\mopBdn
#    84 13748  ghMlo2\mopBdn
#    93 13737  ghMlo1\mopBdn
#    95 13734  ghMlo1\moqBdn
#    97 13651  ghMlo1\moqCdn
#    99 13642  ghMlo0\moqCdn
#   119 13637  ggMlo0\moqCdn
#   121 13594  ggMlo0\loqCdn
#   128 13593  ggMlo0\lorCdn
#   130 13440  ggMlo0\lorCdm
#   144 13359  ggMlo0\lorDdm
#   145 13356  gfMlo0\lorDdm
#   146 13315  gfMlo0\korDdm
#   153 13196  gfMlo0[korDdm
#   161 13135  ffMlo0[korDdm
#   162 13128  ffMlo/[korDdm
#   165 13069  efMlo/[korDdm
#   168 13068  eeMlo/[korDdm
#   171 12951  eeMlo/ZkorDdm
#   174 12890  eeNlo/ZkorDdm
#   195 12775  eeNlo/YkorDdm
#   196 12770  eeNlo.YkorDdm
#   204 12731  eeNlo.YjorDdm
#   206 12618  eeNlo.XjorDdm
#   211 12467  eeNlo.XjorDdl
#   213 12430  eeNlo.XiorDdl
#   215 12281  eeNlo.XiorDdk
#   230 12134  eeNlo.XiorDdj
#   231 12077  deNlo.XiorDdj
#   243 11932  deNlo.XiorDdi
#   245 11873  deOlo.XiorDdi
#   251 11730  deOlo.XiorDdh
#   258 11695  deOlo.XhorDdh
#   260 11692  deOlo-XhorDdh
#   264 11581  deOlo-WhorDdh
#   267 11526  ceOlo-WhorDdh
#   271 11469  cePlo-WhorDdh
#   279 11436  cePlo-WgorDdh
#   284 11295  cePlo-WgorDdg
#   286 11156  cePlo-WgorDdf
#   291 11019  cePlo-WgorDde
#   296 10884  cePlo-WgorDdd
#   298 10829  ceQlo-WgorDdd
#   300 10750  ceQlo-WgorEdd
#   301 10749  ceQlo,WgorEdd
#   305 10696  beQlo,WgorEdd
#   315 10643  beRlo,WgorEdd
#   331 10612  beRlo,WforEdd
#   333 10535  beRlo,WforFdd
#   371 10484  beSlo,WforFdd
#   373 10435  beTlo,WforFdd
#   378 10360  beTlo,WforGdd
#   379 10309  aeTlo,WforGdd
#   384 10262  aeUlo,WforGdd
#   387 10213  `eUlo,WforGdd
#   405 10166  _eUlo,WforGdd
#   415 10121  ^eUlo,WforGdd
#   417  9988  ^eUlo,WforGdc
#   419  9857  ^eUlo,WforGdb
#   423  9828  ^eUlo,WeorGdb
#   425  9785  ]eUlo,WeorGdb
#   429  9712  ]eUlo,WeorHdb
#   430  9671  \eUlo,WeorHdb
#   440  9600  \eUlo,WeorIdb
#   463  9555  \eVlo,WeorIdb
#   466  9486  \eVlo,WeorJdb
#   480  9357  \eVlo,WeorJda
#   487  9248  \eVlo,VeorJda
#   514  9141  \eVlo,UeorJda
#   520  9102  [eVlo,UeorJda
#   521  9059  [eWlo,UeorJda
#   522  8992  [eWlo,UeorKda
#   532  8927  [eWlo,UeorLda
#   540  8864  [eWlo,UeorMda
#   549  8823  [eXlo,UeorMda
#   553  8718  [eXlo,TeorMda
#   568  8591  [eXlo,TeorMd`
#   570  8530  [eXlo,TeorNd`
#   577  8503  [eXlo,TdorNd`
#   579  8478  [eXlo,TcorNd`
#   591  8455  [eXlo,TborNd`
#   595  8330  [eXlo,TborNd_
#   596  8271  [eXlo,TborOd_
#   609  8214  [eXlo,TborPd_
#   611  8193  [eXlo,TaorPd_
#   617  8070  [eXlo,TaorPd^
#   627  8051  [eXlo,T`orPd^
#   630  8014  ZeXlo,T`orPd^
#   632  7959  ZeXlo,T`orQd^
#   645  7920  ZeYlo,T`orQd^
#   649  7883  ZeZlo,T`orQd^
#   651  7866  ZeZlo,T_orQd^
#   655  7813  ZeZlo,T_orRd^
#   662  7798  ZeZlo,T^orRd^
#   669  7785  ZeZlo,T]orRd^
#   670  7734  ZeZlo,T]orSd^
#   672  7685  ZeZlo,T]orTd^
#   674  7650  Ze[lo,T]orTd^
#   675  7603  Ze[lo,T]orUd^
#   678  7500  Ze[lo,S]orUd^
#   681  7455  Ze[lo,S]orVd^
#   685  7334  Ze[lo,S]orVd]
#   688  7233  Ze[lo,R]orVd]
#   691  7222  Ze[lo,R\orVd]
#   693  7187  Ye[lo,R\orVd]
#   697  7178  Ye[lo,R[orVd]
#   706  7171  Ye[lo,RZorVd]
#   713  7072  Ye[lo,QZorVd]
#   725  7029  Ye[lo,QZorWd]
#   727  7024  Ye[lo,QYorWd]
#   728  6991  Xe[lo,QYorWd]
#   740  6872  Xe[lo,QYorWd\
#   754  6755  Xe[lo,QYorWd[
#   756  6714  Xe[lo,QYorXd[
#   759  6683  We[lo,QYorXd[
#   760  6644  We[lo,QYorYd[
#   768  6615  Ve[lo,QYorYd[
#   772  6578  Ve[lo,QYorZd[
#   773  6575  Ve[lo,QXorZd[
#   778  6478  Ve[lo,PXorZd[
#   781  6383  Ve[lo,OXorZd[
#   784  6348  Ve[lo,OXor[d[
#   785  6315  Ve[lo,OXor\d[
#   789  6282  Ve\lo,OXor\d[
#   793  6167  Ve\lo,OXor\dZ
#   801  6054  Ve\lo,OXor\dY
#   804  6053  Ve\lo,OWor\dY
#   819  5942  Ve\lo,OWor\dX
#   826  5911  Ve]lo,OWor\dX
#   832  5802  Ve]lo,OWor\dW
#   834  5773  Ve^lo,OWor\dW
#   835  5666  Ve^lo,OWor\dV
#   862  5573  Ve^lo,NWor\dV
#   867  5542  Ve^lo,NWor]dV
#   878  5451  Ve^lo,MWor]dV
#   893  5424  Ue^lo,MWor]dV
#   900  5395  Ue^lo,MWor^dV
#   904  5306  Ue^lo,LWor^dV
#   910  5279  Ue_lo,LWor^dV
#   925  5252  Ue_lo,LWor_dV
#   939  5227  Te_lo,LWor_dV
#   947  5204  Se_lo,LWor_dV
#   967  5099  Se_lo,LWor_dU
#   969  5074  Se`lo,LWor_dU
#   976  5049  Se`lo,LWor`dU
#   983  5026  Sealo,LWor`dU
#   988  5005  Seblo,LWor`dU
#   997  4982  Seblo,LWoradU
#  1018  4895  Seblo,KWoradU
#  1022  4874  Seblo,KWorbdU
#  1041  4855  Seclo,KWorbdU
#  1044  4770  Seclo,JWorbdU
#  1046  4667  Seclo,JWorbdT
#  1051  4566  Seclo,JWorbdS
#  1062  4483  Seclo,IWorbdS
#  1067  4466  Sedlo,IWorbdS
#  1076  4367  Sedlo,IWorbdR
#  1088  4286  Sedlo,HWorbdR
#  1089  4189  Sedlo,HWorbdQ
#  1097  4168  Redlo,HWorbdQ
#  1116  4149  Redlo,HWorcdQ
#  1121  4054  Redlo,HWorcdP
#  1124  4039  Reelo,HWorcdP
#  1128  3946  Reelo,HWorcdO
#  1129  3867  Reelo,GWorcdO
#  1130  3790  Reelo,FWorcdO
#  1153  3699  Reelo,FWorcdN
#  1155  3680  Qeelo,FWorcdN
#  1157  3667  Qeflo,FWorcdN
#  1169  3592  Qeflo,EWorcdN
#  1173  3575  Peflo,EWorcdN
#  1181  3564  Peglo,EWorcdN
#  1213  3547  Peglo,EWorddN
#  1258  3532  Oeglo,EWorddN
#  1270  3443  Oeglo,EWorddM
#  1273  3428  Oeglo,EWoredM
#  1276  3415  Neglo,EWoredM
#  1284  3328  Neglo,EWoredL
#  1288  3243  Neglo,EWoredK
#  1291  3232  Meglo,EWoredK
#  1293  3219  Meglo,EWorfdK
#  1313  3210  Leglo,EWorfdK
#  1315  3127  Leglo,EWorfdJ
#  1317  3054  Leglo,DWorfdJ
#  1321  2973  Leglo,DWorfdI
#  1329  2894  Leglo,DWorfdH
#  1334  2817  Leglo,DWorfdG
#  1343  2808  Lehlo,DWorfdG
#  1350  2733  Lehlo,DWorfdF
#  1370  2722  Lehlo,DWorgdF
#  1377  2715  Leilo,DWorgdF
#  1394  2642  Leilo,DWorgdE
#  1397  2633  Leilo,DWorhdE
#  1401  2562  Leilo,CWorhdE
#  1407  2493  Leilo,BWorhdE
#  1411  2486  Leilo,BWoridE
#  1417  2481  Leilo,BWorjdE
#  1425  2414  Leilo,AWorjdE
#  1434  2409  Lejlo,AWorjdE
#  1445  2406  Leklo,AWorjdE
#  1450  2405  Lello,AWorjdE
#  1457  2334  Lello,AWorjdD
#  1470  2331  Lello,AWorkdD
#  1488  2266  Lello,@WorkdD
#  1497  2259  Kello,@WorkdD
#  1503  2254  Jello,@WorkdD
#  1511  2251  Iello,@WorkdD
#  1520  2188  Iello,?WorkdD
#  1532  2187  Iello,?WorldD
#  1574  2126  Iello,>WorldD
#  1603  2067  Iello,=WorldD
#  1621  2066  Hello,=WorldD
#  1632  2009  Hello,<WorldD
#  1644  1940  Hello,<WorldC
#  1647  1873  Hello,<WorldB
#  1675  1818  Hello,;WorldB
#  1733  1753  Hello,;WorldA
#  1739  1700  Hello,:WorldA
#  1751  1637  Hello,:World@
#  1795  1586  Hello,9World@
#  1798  1537  Hello,8World@
#  1803  1476  Hello,8World?
#  1816  1417  Hello,8World>
#  1823  1370  Hello,7World>
#  1845  1313  Hello,7World=
#  1854  1268  Hello,6World=
#  1876  1225  Hello,5World=
#  1880  1170  Hello,5World<
#  1925  1117  Hello,5World;
#  1956  1076  Hello,4World;
#  1985  1025  Hello,4World:
#  2000   986  Hello,3World:
#  2001   949  Hello,2World:
#  2002   914  Hello,1World:
#  2003   881  Hello,0World:
#  2011   832  Hello,0World9
#  2027   801  Hello,/World9
#  2048   772  Hello,.World9
#  2054   725  Hello,.World8
#  2055   698  Hello,-World8
#  2074   673  Hello,,World8
#  2077   650  Hello,+World8
#  2108   605  Hello,+World7
#  2130   584  Hello,*World7
#  2166   565  Hello,)World7
#  2170   522  Hello,)World6
#  2227   481  Hello,)World5
#  2263   442  Hello,)World4
#  2271   405  Hello,)World3
#  2288   370  Hello,)World2
#  2305   337  Hello,)World1
#  2314   306  Hello,)World0
#  2337   277  Hello,)World/
#  2344   260  Hello,(World/
#  2355   245  Hello,'World/
#  2359   218  Hello,'World.
#  2381   193  Hello,'World-
#  2405   170  Hello,'World,
#  2423   157  Hello,&World,
#  2442   146  Hello,%World,
#  2468   125  Hello,%World+
#  2471   116  Hello,$World+
#  2473    97  Hello,$World*
#  2489    80  Hello,$World)
#  2519    65  Hello,$World(
#  2523    52  Hello,$World'
#  2550    45  Hello,#World'
#  2570    40  Hello,"World'
#  2622    29  Hello,"World&
#  2634    26  Hello,!World&
#  2669    17  Hello,!World%
#  2678    16  Hello, World%
#  2700     9  Hello, World$
#  2794     4  Hello, World#
#  2795     1  Hello, World"
#  2829     0  Hello, World!
